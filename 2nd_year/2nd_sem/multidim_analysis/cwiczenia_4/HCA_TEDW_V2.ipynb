# %% [markdown]
# # HCA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statistics as st
import scipy.cluster

# %% [markdown]
# # najdalszy sasiad, odleglosc euklidesowa

# %%
dane=pd.read_excel("dane_bio.xlsx",index_col=0)

def autoskalowanie(xi,xm,xstd,lista):
    Zxi=(xi-xm)/xstd
    lista.append(Zxi)
    return lista

def euklides(df):
    n_df=(matrixauto.values)
    for i in range (30):
        for j in range(30):
            odleglosci[i,j]=np.sqrt(np.sum((n_df[i]-n_df[j])**2))
    df_odl[:] = np.tril(df_odl.values, k=-1)
    df_odl.index=['A1','A2','A3','A4','A5','B1','B2','B3','B4','B5','C1','C2','C3','C4','C5',
                  'D1','D2','D3','D4','D5','E1','E2','E3','E4','E5','F1','F2','F3','F4','F5']
    df_odl.columns=['A1','A2','A3','A4','A5','B1','B2','B3','B4','B5','C1','C2','C3','C4','C5',
                      'D1','D2','D3','D4','D5','E1','E2','E3','E4','E5','F1','F2','F3','F4','F5']

    return df_odl


def euklides2(df):
    n_df=(matrixauto.values)
    for i in range (30):
        for j in range(30):
            odleglosci[i,j]=np.sqrt(np.sum((n_df[i]-n_df[j])**2))
    return df_odl1
# Out:
# C:\Users\Kuba\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():

# %%
dane=pd.read_excel("dane_bio.xlsx",index_col=0)

x1m=st.mean(dane["X1"])
x1std=st.stdev(dane["X1"])
x2m=st.mean(dane["X2"])
x2std=st.stdev(dane["X2"])
x3m=st.mean(dane["X3"])
x3std=st.stdev(dane["X3"])
x4m=st.mean(dane["X4"])
x4std=st.stdev(dane["X4"])
x5m=st.mean(dane["X5"])
x5std=st.stdev(dane["X5"])
x6m=st.mean(dane["X6"])
x6std=st.stdev(dane["X6"])
x7m=st.mean(dane["X7"])
x7std=st.stdev(dane["X7"])
x8m=st.mean(dane["X8"])
x8std=st.stdev(dane["X8"])
x9m=st.mean(dane["X9"])
x9std=st.stdev(dane["X9"])
x10m=st.mean(dane["X10"])
x10std=st.stdev(dane["X10"])
X1auto=[]
X2auto=[]
X3auto=[]
X4auto=[]
X5auto=[]
X6auto=[]
X7auto=[]
X8auto=[]
X9auto=[]
X10auto=[]

for i in dane['X1']:
    y=autoskalowanie(i,x1m,x1std,X1auto)
for i in dane['X2']:
    y=autoskalowanie(i,x2m,x2std,X2auto)
for i in dane['X3']:
    y=autoskalowanie(i,x3m,x3std,X3auto)
for i in dane['X4']:
    y=autoskalowanie(i,x4m,x4std,X4auto)
for i in dane['X5']:
    y=autoskalowanie(i,x5m,x5std,X5auto)
for i in dane['X6']:
    y=autoskalowanie(i,x6m,x6std,X6auto)
for i in dane['X7']:
    y=autoskalowanie(i,x7m,x7std,X7auto)
for i in dane['X8']:
    y=autoskalowanie(i,x8m,x8std,X8auto)
for i in dane['X9']:
    y=autoskalowanie(i,x9m,x9std,X9auto)
for i in dane['X10']:
    y=autoskalowanie(i,x10m,x10std,X10auto)

    
matrixauto=pd.DataFrame(X1auto,columns=["ZX1"])
matrixauto.index=['A1','A2','A3','A4','A5','B1','B2','B3','B4','B5','C1','C2','C3','C4','C5',
                  'D1','D2','D3','D4','D5','E1','E2','E3','E4','E5','F1','F2','F3','F4','F5']

matrixauto['ZX2'] = X2auto
matrixauto['ZX3'] = X3auto
matrixauto['ZX4'] = X4auto
matrixauto['ZX5'] = X5auto
matrixauto['ZX6'] = X6auto
matrixauto['ZX7'] = X7auto
matrixauto['ZX8'] = X8auto
matrixauto['ZX9'] = X9auto
matrixauto['ZX10'] = X10auto

odleglosci=np.zeros((30,30))
df_odl=pd.DataFrame(odleglosci)
df_odl1=pd.DataFrame(odleglosci)
# Out:
# C:\Users\Kuba\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():

# %%
X=euklides(matrixauto)
Y=euklides2(matrixauto)

# %%
y=df_odl1.to_numpy()
triangle_flat=y.flatten()
min1=min(i for i in triangle_flat if i>0)
coord=np.where(df_odl1==min1)

# %%
print(min1,'\n',coord)
# Out:
# 0.8350986680573014
#  (array([7], dtype=int64), array([5], dtype=int64))

# %%
koord1=max((coord)[0])
koord2=min((coord)[1])
list_koord2=df_odl1.iloc[koord1].index,df_odl1.iloc[koord2].index

# %%
df_odl1=euklides2(matrixauto) #tego nie brac do loopa

# %%
df_odl1
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.000000  3.859078  2.447985  2.388159  3.844822  5.036252  5.992023
# 1   3.859078  0.000000  3.406620  3.267078  1.037613  6.608015  7.279434
# 2   2.447985  3.406620  0.000000  0.906805  3.044801  5.312622  5.663067
# 3   2.388159  3.267078  0.906805  0.000000  2.751215  5.274501  5.745157
# 4   3.844822  1.037613  3.044801  2.751215  0.000000  6.322510  6.921335
# 5   5.036252  6.608015  5.312622  5.274501  6.322510  0.000000  1.666213
# 6   5.992023  7.279434  5.663067  5.745157  6.921335  1.666213  0.000000
# 7   5.189822  6.800181  5.208177  5.229529  6.459803  0.835099  1.199873
# 8   5.257358  5.292113  5.503423  5.270878  5.042702  2.830695  3.834572
# 9   4.945842  6.181939  5.132377  4.951742  5.777265  1.266463  2.288495
# 10  3.741403  1.855228  3.412936  3.307569  2.086782  6.171263  6.806791
# 11  5.520682  3.216776  3.813753  3.820163  2.884553  6.966430  6.993340
# 12  2.874214  3.322021  2.057247  2.277429  3.184919  4.936685  5.298221
# 13  2.541354  4.455918  2.654413  2.768740  4.340615  5.262666  5.806584
# 14  2.020708  3.649162  2.954933  2.921661  3.714420  5.498885  6.331907
# 15  4.935951  3.133465  3.293143  3.143208  2.591208  6.553465  6.738059
# 16  3.485742  3.868151  2.154952  2.655120  3.759297  5.531885  5.653217
# 17  2.369381  4.111026  2.278409  2.358425  3.957559  5.063447  5.639499
# 18  1.765347  4.478657  2.911062  2.999918  4.494659  5.090197  5.906261
# 19  3.974375  1.819430  3.273154  2.948042  1.439183  6.326819  6.917335
# 20  4.774755  6.489416  5.498224  5.327381  6.213339  1.302256  2.862109
# 21  6.126127  7.119822  5.596616  5.480675  6.573595  2.233071  1.689843
# 22  5.418611  5.637385  5.008676  4.837509  5.201448  2.297936  2.551893
# 23  5.162085  6.025263  5.523175  5.529598  5.886567  1.762042  2.688603
# 24  5.363662  6.468643  5.793644  5.877096  6.391129  1.840749  2.610865
# 25  3.208313  2.101530  2.844865  2.463305  1.849989  6.169275  6.814171
# 2   5.793644  2.844865  2.113260  2.204138  1.450593  3.303796
# 3   5.877096  2.463305  2.104037  2.176940  1.579406  2.806696
# 4   6.391129  1.849989  2.977155  3.614151  3.841643  1.838641
# 5   1.840749  6.169275  5.195033  5.182851  5.594403  6.293410
# 6   2.610865  6.814171  5.567805  5.803612  5.778866  7.101257
# 7   2.239583  6.274606  5.166115  5.207311  5.407689  6.480105
# 8   2.839634  5.329337  5.125739  5.432353  6.110231  5.168647
# 9   2.326611  5.634937  4.839573  4.948091  5.392758  5.669584
# 10  5.993434  1.986007  2.787743  3.212798  3.884115  2.530889
# 11  7.039327  3.363784  3.559489  4.591788  4.046031  4.085811
# 12  5.004840  2.481166  1.414766  1.788328  2.101568  3.272240
# 13  5.594803  3.422527  2.647079  1.882008  2.387118  4.041039
# 14  5.540295  2.678779  2.486241  1.614018  3.048408  3.123965
# 15  6.934618  3.082691  3.439257  4.184994  3.721723  3.519744
# 16  5.652624  3.127087  1.890647  2.265043  2.124485  3.898711
# 17  5.510149  3.060940  2.373807  1.654708  2.328933  3.553138
# 18  5.381755  3.490896  2.878075  1.711937  3.066859  3.746117
# 19  6.438034  1.643097  2.796313  3.336211  3.787646  1.776454
# 20  2.221363  5.993399  5.272687  5.097217  5.821182  5.929335
# 21  3.608634  6.612404  5.632687  5.937117  5.727015  6.803807
# 22  2.974161  5.373041  4.737554  5.201246  5.366028  5.497400
# 23  0.884810  5.836427  5.019728  5.200277  5.950691  5.896652
# 24  0.000000  6.238411  5.276210  5.393005  6.144928  6.388012
# 25  6.238411  0.000000  1.879929  2.361723  3.064054  1.060995
# 26  5.276210  1.879929  0.000000  1.425425  1.908840  2.630121
# 27  5.393005  2.361723  1.425425  0.000000  1.973351  2.863010
# 28  6.144928  3.064054  1.908840  1.973351  0.000000  3.720051
# 29  6.388012  1.060995  2.630121  2.863010  3.720051  0.000000
#
# [30 rows x 30 columns]

# %%
wektor=[]
for i in range(len(df_odl1)):
    
    if df_odl1.iloc[koord1,i]==0:
        wektor.append(df_odl1.iloc[koord1,i])
        
    elif df_odl1.iloc[koord2,i]==0:
        wektor.append(df_odl1.iloc[koord2,i])
    
    elif (df_odl1.iloc[koord2,i])>(df_odl1.iloc[koord1,i]):
        wektor.append(df_odl1.iloc[koord2,i])
    
    elif df_odl1.iloc[koord2,i]<df_odl1.iloc[koord1,i]:
        wektor.append(df_odl1.iloc[koord1,i])
wektor
# Out:
# [5.18982151643788,
#  6.800180667822808,
#  5.312621938785493,
#  5.274501300137263,
#  6.459802727448987,
#  0.0,
#  1.6662133641650594,
#  0.0,
#  3.3072031308678755,
#  1.565272712212543,
#  6.332023666534852,
#  6.966430258096824,
#  4.936685185667516,
#  5.262666322962077,
#  5.642836178261796,
#  6.553465019682665,
#  5.53188527026546,
#  5.072801098580238,
#  5.1926015561841075,
#  6.482102999119702,
#  1.9378377271906198,
#  2.2330713734586185,
#  2.422628880540256,
#  2.2470193263592164,
#  2.239583122012459,
#  6.274606347743855,
#  5.195033188806296,
#  5.207310664560192,
#  5.594403237845205,
#  6.480105390144552]

# %%
df_odl1.iloc[koord2]=wektor
df_odl1.iloc[:,koord2]=wektor
df_odl1=df_odl1.drop(koord1,axis=0)
df_odl1=df_odl1.drop(koord1,axis=1)

# %%
df_odl1
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.000000
# 3   5.877096  2.463305  2.104037  2.176940  1.579406  2.806696
# 4   6.391129  1.849989  2.977155  3.614151  3.841643  1.838641
# 31  2.239583  6.274606  5.195033  5.207311  5.594403  6.480105
# 6   2.610865  6.814171  5.567805  5.803612  5.778866  7.101257
# 8   2.839634  5.329337  5.125739  5.432353  6.110231  5.168647
# 9   2.326611  5.634937  4.839573  4.948091  5.392758  5.669584
# 10  5.993434  1.986007  2.787743  3.212798  3.884115  2.530889
# 11  7.039327  3.363784  3.559489  4.591788  4.046031  4.085811
# 12  5.004840  2.481166  1.414766  1.788328  2.101568  3.272240
# 13  5.594803  3.422527  2.647079  1.882008  2.387118  4.041039
# 14  5.540295  2.678779  2.486241  1.614018  3.048408  3.123965
# 15  6.934618  3.082691  3.439257  4.184994  3.721723  3.519744
# 16  5.652624  3.127087  1.890647  2.265043  2.124485  3.898711
# 17  5.510149  3.060940  2.373807  1.654708  2.328933  3.553138
# 18  5.381755  3.490896  2.878075  1.711937  3.066859  3.746117
# 19  6.438034  1.643097  2.796313  3.336211  3.787646  1.776454
# 20  2.221363  5.993399  5.272687  5.097217  5.821182  5.929335
# 21  3.608634  6.612404  5.632687  5.937117  5.727015  6.803807
# 22  2.974161  5.373041  4.737554  5.201246  5.366028  5.497400
# 23  0.884810  5.836427  5.019728  5.200277  5.950691  5.896652
# 24  0.000000  6.238411  5.276210  5.393005  6.144928  6.388012
# 25  6.238411  0.000000  1.879929  2.361723  3.064054  1.060995
# 26  5.276210  1.879929  0.000000  1.425425  1.908840  2.630121
# 27  5.393005  2.361723  1.425425  0.000000  1.973351  2.863010
# 28  6.144928  3.064054  1.908840  1.973351  0.000000  3.720051
# 29  6.388012  1.060995  2.630121  2.863010  3.720051  0.000000
#
# [29 rows x 29 columns]

# %%
i=1
while np.size(df_odl)>=4:
    y=df_odl1.to_numpy()
    triangle_flat=y.flatten()
    min1=min(i for i in triangle_flat if i>0)
    coord=np.where(df_odl1==min1)
    
    koord1=max((coord)[0])
    koord2=min((coord)[1])
    list_koord2=df_odl1.iloc[koord1].index,df_odl1.iloc[koord2].index
    
    print(koord1,'\n',koord2)
    
    wektor=[]
    for i in range(len(df_odl1)):

        if df_odl1.iloc[koord1,i]==0:
            wektor.append(df_odl1.iloc[koord1,i])

        elif df_odl1.iloc[koord2,i]==0:
            wektor.append(df_odl1.iloc[koord2,i])

        elif (df_odl1.iloc[koord2,i])>(df_odl1.iloc[koord1,i]):
            wektor.append(df_odl1.iloc[koord2,i])

        elif df_odl1.iloc[koord2,i]<df_odl1.iloc[koord1,i]:
            wektor.append(df_odl1.iloc[koord1,i])
    
    df_odl1.iloc[koord2]=wektor
    df_odl1.iloc[:,koord2]=wektor
    df_odl1=df_odl1.drop(koord1,axis=0)
    df_odl1=df_odl1.drop(koord1,axis=1)
    
    new_name=nazwy_lista[i]
    df_odl1.rename(columns={df_odl1.columns[koord2]:new_name},inplace=True)
    df_odl1.rename(index={df_odl1.index[koord2]:new_name},inplace=True)
    i=i+1
    
df_odl1
# Out:
# 23
#  22
# 3
#  2
# 3
#  1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14612\2803603992.py in <module>
#      29     df_odl1.iloc[koord2]=wektor
#      30     df_odl1.iloc[:,koord2]=wektor
# ---> 31     df_odl1=df_odl1.drop(koord1,axis=0)
#      32     df_odl1=df_odl1.drop(koord1,axis=1)
#      33
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265         for axis, labels in axes.items():
#    4266             if labels is not None:
# -> 4267                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4268
#    4269         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4310             else:
# -> 4311                 new_axis = axis.drop(labels, errors=errors)
#    4312             indexer = axis.get_indexer(new_axis)
#    4313
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6659         if mask.any():
#    6660             if errors != "ignore":
# -> 6661                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6662             indexer = indexer[~mask]
#    6663         return self.delete(indexer)
#
# KeyError: '[3] not found in axis'

# %%
"""    
dane=pd.read_excel("dane_bio.xlsx",index_col=0)
    
x1m=st.mean(dane["X1"])
x1std=st.stdev(dane["X1"])
x2m=st.mean(dane["X2"])
x2std=st.stdev(dane["X2"])
x3m=st.mean(dane["X3"])
x3std=st.stdev(dane["X3"])
x4m=st.mean(dane["X4"])
x4std=st.stdev(dane["X4"])
x5m=st.mean(dane["X5"])
x5std=st.stdev(dane["X5"])
x6m=st.mean(dane["X6"])
x6std=st.stdev(dane["X6"])
x7m=st.mean(dane["X7"])
x7std=st.stdev(dane["X7"])
x8m=st.mean(dane["X8"])
x8std=st.stdev(dane["X8"])
x9m=st.mean(dane["X9"])
x9std=st.stdev(dane["X9"])
x10m=st.mean(dane["X10"])
x10std=st.stdev(dane["X10"])
X1auto=[]
X2auto=[]
X3auto=[]
X4auto=[]
X5auto=[]
X6auto=[]
X7auto=[]
X8auto=[]
X9auto=[]
X10auto=[]
    
for i in dane['X1']:
    y=autoskalowanie(i,x1m,x1std,X1auto)
for i in dane['X2']:
    y=autoskalowanie(i,x2m,x2std,X2auto)
for i in dane['X3']:
    y=autoskalowanie(i,x3m,x3std,X3auto)
for i in dane['X4']:
    y=autoskalowanie(i,x4m,x4std,X4auto)
for i in dane['X5']:
    y=autoskalowanie(i,x5m,x5std,X5auto)
for i in dane['X6']:
    y=autoskalowanie(i,x6m,x6std,X6auto)
for i in dane['X7']:
    y=autoskalowanie(i,x7m,x7std,X7auto)
for i in dane['X8']:
    y=autoskalowanie(i,x8m,x8std,X8auto)
for i in dane['X9']:
    y=autoskalowanie(i,x9m,x9std,X9auto)
for i in dane['X10']:
    y=autoskalowanie(i,x10m,x10std,X10auto)
    
matrixauto=pd.DataFrame(X1auto,columns=["ZX1"])
matrixauto.index=['A1','A2','A3','A4','A5','B1','B2','B3','B4','B5','C1','C2','C3','C4','C5',
                  'D1','D2','D3','D4','D5','E1','E2','E3','E4','E5','F1','F2','F3','F4','F5']
    
matrixauto['ZX2'] = X2auto
matrixauto['ZX3'] = X3auto
matrixauto['ZX4'] = X4auto
matrixauto['ZX5'] = X5auto
matrixauto['ZX6'] = X6auto
matrixauto['ZX7'] = X7auto
matrixauto['ZX8'] = X8auto
matrixauto['ZX9'] = X9auto
matrixauto['ZX10'] = X10auto

odleglosci=np.zeros((30,30))
df_odl=pd.DataFrame(odleglosci)
df_odl1=pd.DataFrame(odleglosci)
    
euklides(matrixauto)
"""
# Out:
# C:\Users\Kuba\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4356\1560700775.py in <module>
#      80
#      81     lista_koord_name=[]
# ---> 82     koord1=max(coord)[0]
#      83     koord2=min(coord)[0]
#      84     list_koord2=df_odl.iloc[koord1].index,df_odl.iloc[koord2].index
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
