# %% [markdown]
# # Techniki eksploracji danych wielowymiarowych 20.02

# %% [markdown]
# # Cwiczenie 1

# %%
import pandas as pd
import numpy as np
import random

# %% [markdown]
# # 1

# %%
A=[]
i=0
while i<10:
    x=random.randrange(1,20)
    A.append(x)
    i=i+1
wektorA=np.vstack(A)
print(wektorA)
# Out:
# [[ 1]
#  [18]
#  [ 6]
#  [ 3]
#  [ 5]
#  [ 9]
#  [ 2]
#  [ 8]
#  [ 4]
#  [ 6]]

# %% [markdown]
# # 2

# %%
B=[]
i=0
while i<10:
    x=random.uniform(0,1)
    B.append(x)
    i=i+1
wektorB=np.vstack(B)
print(wektorB)
# Out:
# [[0.72235659]
#  [0.75836388]
#  [0.70758816]
#  [0.92980083]
#  [0.40377044]
#  [0.4354779 ]
#  [0.91856863]
#  [0.14835865]
#  [0.95876042]
#  [0.60797136]]

# %% [markdown]
# # 3

# %%
wektorC=wektorA*wektorB
print(wektorC)
# Out:
# [[ 0.72235659]
#  [13.65054988]
#  [ 4.24552897]
#  [ 2.7894025 ]
#  [ 2.01885222]
#  [ 3.91930108]
#  [ 1.83713726]
#  [ 1.18686918]
#  [ 3.83504167]
#  [ 3.64782815]]

# %% [markdown]
# # 4

# %%
c=2
wektor4=wektorA*c
print(wektor4)
# Out:
# [[ 2]
#  [36]
#  [12]
#  [ 6]
#  [10]
#  [18]
#  [ 4]
#  [16]
#  [ 8]
#  [12]]

# %% [markdown]
# # 5

# %%
W=np.random.randint(100, size=(4,4))
print(W)
# Out:
# [[58 56 84 55]
#  [80  4 13 65]
#  [29 48 33 55]
#  [60 85 30 66]]

# %% [markdown]
# # 6

# %%
diag=np.diagonal(W)
print(diag)
# Out:
# [58  4 33 66]

# %% [markdown]
# # 7

# %%
print(f'{W.transpose()}')
# Out:
# [[58 80 29 60]
#  [56  4 48 85]
#  [84 13 33 30]
#  [55 65 55 66]]

# %% [markdown]
# # Ćwiczenie 2

# %% [markdown]
# # 1

# %%
dane=pd.read_csv('nfloffenseweek3.csv')
pd.read_csv('nfloffenseweek3.csv')
# Out:
#     rank                   team  games  points_scored  total_yards  \
# 0      1       Baltimore Ravens      3             99         1141
# 1      2          Detroit Lions      3             95         1227
# 2      3          Buffalo Bills      3             91         1324
# 3      4     Kansas City Chiefs      3             88         1122
# 4      5    Philadelphia Eagles      3             86         1341
# 5      6       Cleveland Browns      3             85         1136
# 6      7   Jacksonville Jaguars      3             84         1127
# 7      8         Miami Dolphins      3             83         1066
# 8      9        Atlanta Falcons      3             80         1063
# 9     10     Cincinnati Bengals      3             64         1016
# 10    11      Las Vegas Raiders      3             64         1040
# 11    12  Washington Commanders      3             63         1026
# 12    13      Arizona Cardinals      3             62         1060
# ...

# %% [markdown]
# # 2

# %%
dane['team'].value_counts()['Miami Dolphins']
# Out:
# 1

# %%
i = dane.index
index = dane["team"] == 'Arizona Cardinals'
result = i[index]
result.tolist()
# Out:
# [12]

# %% [markdown]
# # 3

# %%
wiersz1=random.randrange(1,32)
wiersz2=random.randrange(1,32)
print(wiersz1,wiersz2)
# Out:
# 15 6

# %%
dane=dane.drop([wiersz1,wiersz2])
dane
# Out:
#     rank                   team  games  points_scored  total_yards  \
# 0      1       Baltimore Ravens      3             99         1141
# 1      2          Detroit Lions      3             95         1227
# 2      3          Buffalo Bills      3             91         1324
# 3      4     Kansas City Chiefs      3             88         1122
# 4      5    Philadelphia Eagles      3             86         1341
# 5      6       Cleveland Browns      3             85         1136
# 7      8         Miami Dolphins      3             83         1066
# 8      9        Atlanta Falcons      3             80         1063
# 9     10     Cincinnati Bengals      3             64         1016
# 10    11      Las Vegas Raiders      3             64         1040
# 11    12  Washington Commanders      3             63         1026
# 12    13      Arizona Cardinals      3             62         1060
# 13    14      Carolina Panthers      3             62          829
# ...

# %% [markdown]
# # 4

# %%
dane=dane.iloc[:,[2,1,0]+list(range(3,len(dane.columns)))]
dane=dane.iloc[[len(dane)-1]+list(range(1,len(dane)-1))+[0],:]
dane
# Out:
#     games                   team  rank  points_scored  total_yards  \
# 31      3     Indianapolis Colts    32             40          994
# 1       3          Detroit Lions     2             95         1227
# 2       3          Buffalo Bills     3             91         1324
# 3       3     Kansas City Chiefs     4             88         1122
# 4       3    Philadelphia Eagles     5             86         1341
# 5       3       Cleveland Browns     6             85         1136
# 7       3         Miami Dolphins     8             83         1066
# 8       3        Atlanta Falcons     9             80         1063
# 9       3     Cincinnati Bengals    10             64         1016
# 10      3      Las Vegas Raiders    11             64         1040
# 11      3  Washington Commanders    12             63         1026
# 12      3      Arizona Cardinals    13             62         1060
# 13      3      Carolina Panthers    14             62          829
# ...

# %% [markdown]
# # 5

# %%
dane.to_csv('dane.csv', index=False)
dane.to_excel('dane.xlsx')

# %% [markdown]
# # 6

# %%
lista_kolumn=(dane.columns)
lista_kolumn
# Out:
# Index(['games', 'team', 'rank', 'points_scored', 'total_yards',
#        'offensive_plays', 'yards_per_play', 'turnovers_lost', 'fumbles_lost',
#        '1st_downs', 'passes_completed', 'passes_attempted', 'passing_yards',
#        'passing_touchdowns', 'passing_interceptions',
#        'net_yards_per_pass_attempt', 'passing_1st_downs', 'rushing_attempts',
#        'rushing_yards', 'rushing_touchdowns', 'rushing_yards_per_attempt',
#        'rushing_1st_downs', 'penalties', 'penalty_yards', '1st_down_penalties',
#        'percentage_scoring_drives', 'percentage_turnover_drives',
#        'expected_points'],
#       dtype='object')

# %% [markdown]
# # 7

# %%
lista_kolumn[:5]
# Out:
# Index(['games', 'team', 'rank', 'points_scored', 'total_yards'], dtype='object')

# %%
lista_kolumn[-7:]
# Out:
# Index(['rushing_1st_downs', 'penalties', 'penalty_yards', '1st_down_penalties',
#        'percentage_scoring_drives', 'percentage_turnover_drives',
#        'expected_points'],
#       dtype='object')

# %% [markdown]
# # 8

# %%
dane.iloc[6, 3]
# Out:
# 83

# %% [markdown]
# # 9

# %%
kolumna_6=dane['offensive_plays']
kolumna_6
# Out:
# 31    207
# 1     203
# 2     213
# 3     180
# 4     208
# 5     210
# 7     167
# 8     181
# 9     227
# 10    182
# 11    216
# 12    222
# 13    163
# 14    175
# 16    197
# 17    195
# 18    174
# 19    222
# 20    159
# 21    186
# 22    187
# 23    168
# 24    183
# 25    184
# 26    188
# 27    165
# 28    189
# 29    184
# 30    199
# 0     166
# Name: offensive_plays, dtype: int64

# %%
dane=dane.drop(columns=['offensive_plays'])

# %%
pd.concat([dane, kolumna_6],axis=1)
# Out:
#     games                   team  rank  points_scored  total_yards  \
# 31      3     Indianapolis Colts    32             40          994
# 1       3          Detroit Lions     2             95         1227
# 2       3          Buffalo Bills     3             91         1324
# 3       3     Kansas City Chiefs     4             88         1122
# 4       3    Philadelphia Eagles     5             86         1341
# 5       3       Cleveland Browns     6             85         1136
# 7       3         Miami Dolphins     8             83         1066
# 8       3        Atlanta Falcons     9             80         1063
# 9       3     Cincinnati Bengals    10             64         1016
# 10      3      Las Vegas Raiders    11             64         1040
# 11      3  Washington Commanders    12             63         1026
# 12      3      Arizona Cardinals    13             62         1060
# 13      3      Carolina Panthers    14             62          829
# ...

# %% [markdown]
# # 27.02 Ćwiczenia 2

# %% [markdown]
# # zadanie 1 (z kartki)

# %%
dane=pd.read_csv('nfloffenseweek3.csv')
pd.read_csv('nfloffenseweek3.csv')
# Out:
#     rank                   team  games  points_scored  total_yards  \
# 0      1       Baltimore Ravens      3             99         1141
# 1      2          Detroit Lions      3             95         1227
# 2      3          Buffalo Bills      3             91         1324
# 3      4     Kansas City Chiefs      3             88         1122
# 4      5    Philadelphia Eagles      3             86         1341
# 5      6       Cleveland Browns      3             85         1136
# 6      7   Jacksonville Jaguars      3             84         1127
# 7      8         Miami Dolphins      3             83         1066
# 8      9        Atlanta Falcons      3             80         1063
# 9     10     Cincinnati Bengals      3             64         1016
# 10    11      Las Vegas Raiders      3             64         1040
# 11    12  Washington Commanders      3             63         1026
# 12    13      Arizona Cardinals      3             62         1060
# ...

# %%
import scipy.stats as stats

# %%
dane=pd.read_csv('nfloffenseweek3.csv')
dane=dane.drop(columns=['team','rank'])
srednia=dane.mean()
minimum=dane.min()
maximum=dane.max()
rozstep=(dane.max()-dane.min())
sr_rozk=rozstep/2
odchyl_std=np.std(dane)
skosnosc=dane.skew()
# Out:
# games                         0.000000
# points_scored                 0.743409
# total_yards                   0.294444
# offensive_plays               0.244825
# yards_per_play                0.546119
# turnovers_lost                0.377095
# fumbles_lost                  0.170529
# 1st_downs                     0.069250
# passes_completed             -0.698003
# passes_attempted             -0.191506
# passing_yards                -0.736258
# passing_touchdowns            0.834311
# passing_interceptions         0.624254
# net_yards_per_pass_attempt    0.417963
# passing_1st_downs            -0.753629
# rushing_attempts              0.579836
# rushing_yards                 0.674914
# rushing_touchdowns            0.499761
# rushing_yards_per_attempt    -0.019443
# rushing_1st_downs             0.502611
# penalties                     0.396504
# penalty_yards                 0.229210
# 1st_down_penalties            0.053626
# percentage_scoring_drives     0.395962
# ...
