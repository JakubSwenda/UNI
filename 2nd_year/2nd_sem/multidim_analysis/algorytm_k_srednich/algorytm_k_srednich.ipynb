# A5 -0.643442 -0.271930 -1.182297
# B1  0.348334 -0.366663  0.911362
# B2  0.747508 -0.061130  0.409629
# B3  0.266102 -0.154936  0.921964
# B4  0.017690 -0.806663 -0.504067
# B5 -0.102075 -0.343379  0.821580
# C1 -0.088224  0.483626 -1.426496
# C2  0.538671  0.637143 -2.276834
# C3  0.054550  0.770758 -0.498251
# C4  0.353032  0.987919  0.943923
# C5 -0.394371  0.547902  0.535073
# D1  0.925182 -0.708321 -1.092458
# D2  0.539895  0.004167 -0.691662
# D3  0.538066 -0.337993  0.918939
# D4  0.139127 -0.394678  1.252011
# D5  0.175104 -0.485174 -1.014757
# E1  0.006304 -0.502722  1.332504
# E2  0.736544 -0.311096  0.941796
# E3  0.790965 -0.348222 -0.271639
# E4 -0.061687 -0.647626 -0.505068
# E5 -0.075731 -0.348001 -0.517231
# F1 -0.665674  0.626305 -0.566336
# F2 -0.469815  0.803917 -0.441389
# F3 -0.396134  0.577055  0.602225
# F4 -0.215275  0.885288  0.778861
# F5 -0.822539  0.272163 -0.313765

# %%
lista=['PC3','PC4','PC5','PC6','PC7','PC8','PC9','PC10']

# %%
dane=dane.drop(lista,axis=1)

# %%
min1=min(dane['PC1'])
max1=max(dane['PC1'])
min2=min(dane['PC2'])
max2=max(dane['PC2'])

# %%
lista_punktow_PC1=[]
for i in range(0,3):
    x=rd.uniform(min1, max1)
    lista_punktow_PC1.append(x)

# %%
lista_punktow_PC1
# Out:
# [0.6016391372128602, 1.1854547175770533, 1.7289582070735219]

# %%
lista_punktow_PC2=[]
for i in range(0,3):
    x=rd.uniform(min2, max2)
    lista_punktow_PC2.append(x)

# %%
lista_punktow_PC2
# Out:
# [-0.6801221530324539, -1.621933218095605, -1.8767869242459976]

# %%
wspolrzedne={lista_punktow_PC1[0]:lista_punktow_PC2[0],
             lista_punktow_PC1[1]:lista_punktow_PC2[1],
             lista_punktow_PC1[2]:lista_punktow_PC2[2]}

# %%
wspolrzedne
# Out:
# {0.6016391372128602: -0.6801221530324539,
#  1.1854547175770533: -1.621933218095605,
#  1.7289582070735219: -1.8767869242459976}

# %%
result = wspolrzedne.items()
data = list(result)
wspolrzedne_array = np.array(data)
print(wspolrzedne_array)
# Out:
# [[ 0.60163914 -0.68012215]
#  [ 1.18545472 -1.62193322]
#  [ 1.72895821 -1.87678692]]

# %%
print(dane)
# Out:
#          PC1       PC2
# A1  0.785477 -0.989986
# A2  1.266448 -0.098023
# A3  0.478377 -0.855821
# A4  0.658394 -0.287575
# A5  1.031126  0.307710
# B1 -2.354765  0.856197
# B2 -2.910756  0.913286
# B3 -2.430550  0.562682
# B4 -1.541822  1.825125
# B5 -1.826913  1.539126
# C1  0.904284 -0.869517
# C2  0.546051 -0.356738
# C3  0.363649 -1.124673
# C4  0.405105 -1.951579
# C5  0.976966 -1.535084
# D1  1.328164  0.214311
# D2  1.063922 -1.235588
# D3  1.331047 -1.209723
# D4  1.526279 -1.345653
# D5  1.790360  0.402439
# E1 -1.831015  1.260726
# E2 -2.707096  1.756017
# E3 -1.821466  1.649863
# E4 -1.979685  1.104867
# E5 -2.315847  0.625007
# F1  1.927803  0.045248
# F2  1.126169 -0.175659
# F3  1.326164 -0.773699
# F4  0.798393 -0.789475
# F5  2.085735  0.536189

# %%
lista_dystansow_punkt1=[]
lista_dystansow_punkt2=[]
lista_dystansow_punkt3=[]

# %%
for i in range(0,30):
    point1=np.array((dane['PC1'][i],dane['PC2'][i]))
    point2=wspolrzedne_array[0]
    distance=np.linalg.norm(point1 - point2)
    lista_dystansow_punkt1.append(distance)
for i in range(0,30):
    point1=np.array((dane['PC1'][i],dane['PC2'][i]))
    point2=wspolrzedne_array[1]
    distance=np.linalg.norm(point1 - point2)
    lista_dystansow_punkt2.append(distance)
for i in range(0,30):
    point1=np.array((dane['PC1'][i],dane['PC2'][i]))
    point2=wspolrzedne_array[2]
    distance=np.linalg.norm(point1 - point2)
    lista_dystansow_punkt3.append(distance)

# %%
print(lista_dystansow_punkt1,'\n',
lista_dystansow_punkt2,'\n',
lista_dystansow_punkt3,'\n')
# Out:
# [0.3602941161426048, 0.8836346484703326, 0.2146247133566988, 0.3966282800806278, 1.0771588091001494, 3.3317562005247146, 3.856924221105153, 3.2770003327496253, 3.297072664661993, 3.289821768330083, 0.35702091757868, 0.328126818679239, 0.5042469432730403, 1.2865561875768325, 0.9337182551649105, 1.1523234161307747, 0.7226673781420229, 0.9013951863449081, 1.13924972744432, 1.6077925726574922, 3.11202504906054, 4.108831996169513, 3.3615872899742683, 3.1383785034172895, 3.1961046986953416, 1.5115799249185287, 0.7277459752804517, 0.7305428120103398, 0.22510021597112906, 1.918841634104919]
#  [0.7478901622490886, 1.5260609013438864, 1.0425385730605514, 1.4346790110626007, 1.9358047697430714, 4.321375006531221, 4.8172889276533875, 4.224693059880183, 4.395480361084277, 4.366538010264135, 0.8032358608698228, 1.4175879984070932, 0.9605373841659971, 0.8471192241167839, 0.22585478448912322, 1.8417817559822993, 0.40500957240383156, 0.43716656298590906, 0.43873881090084355, 2.112816873417484, 4.172387406822721, 5.153881695221974, 4.443672189783477, 4.177744317941816, 4.1602705522294166, 1.8249865774985974, 1.4474884906760352, 0.8598259628258242, 0.9180432177241268, 2.3383744628455876]
#  [1.294825484718488, 1.8379108392239047, 1.6144115555156906, 1.9161683872977364, 2.2932502068335436, 4.9138572229258815, 5.414004802135454, 4.822086113905152, 4.939853628988777, 4.930789024791484, 1.3017993695944283, 1.9260887931987098, 1.5587636553418731, 1.3259637417489156, 0.8259862952324204, 2.129161411628314, 0.9238011923252332, 0.77672871768627, 0.5684910495362163, 2.2800533054844534, 4.74525025080696, 5.733745614996621, 5.004275317949665, 4.758602012400645, 4.755987656581552, 1.932293764216323, 1.8047686809649304, 1.1743281405686805, 1.4311529563795462, 2.439209121195377]

# %%
len(lista_dystansow_punkt1)
# Out:
# 30
